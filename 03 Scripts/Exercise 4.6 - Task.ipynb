# %% [markdown]
# # Exercise 4.6:

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# Question 3: import the orders_products_combined dataframe from the pickle file

df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

df_prods = pd.read_csv(os.path.join(path,'02 Data','Prepared Data', 'products_clean.csv' ), index_col = False)
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Question 4: check the shape of the imported dataframe
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                    -1.0         196                  1          0   both
# 1                    -1.0       14084                  2          0   both
# 2                    -1.0       12427                  3          0   both
# 3                    -1.0       26088                  4          0   both
# 4                    -1.0       26405                  5          0   both

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# to be able to merge the two dataframe I have to drop the _merge column from df_orders_products_combined so I can 
#have the same name column in the final merged dataframe. 
df_orders_products_combined = df_orders_products_combined.drop(columns = ['_merge'])

# %%
# Question 5: Determine a suitable way to combine the two dataframes
df_merged = df_prods.merge(df_orders_products_combined, on = 'product_id', indicator = True)

# %%
# Question 6: Confirm the results of the merge
df_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                  6                 11
# 1   1977647      138            30                  6                 17
# 2    389851      709             2                  0                 21
# 3    652770      764             1                  3                 13
# 4   1813452      764             3                  4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Export data to pkl

df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
